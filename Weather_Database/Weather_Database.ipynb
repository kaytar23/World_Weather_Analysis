# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# samarai
# Processing Record 6 of Set 7 | lakselv
# Processing Record 7 of Set 7 | opuwo
# Processing Record 8 of Set 7 | san carlos de bariloche
# Processing Record 9 of Set 7 | san quintin
# Processing Record 10 of Set 7 | balabac
# Processing Record 11 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 7 | talnakh
# Processing Record 13 of Set 7 | buin
# Processing Record 14 of Set 7 | guarapari
# Processing Record 15 of Set 7 | tecolutla
# Processing Record 16 of Set 7 | jackson
# Processing Record 17 of Set 7 | sobolevo
# Processing Record 18 of Set 7 | soderhamn
# Processing Record 19 of Set 7 | kodiak
# Processing Record 20 of Set 7 | midleton
# Processing Record 21 of Set 7 | tongzi
# Processing Record 22 of Set 7 | kutum
# Processing Record 23 of Set 7 | paamiut
# Processing Record 24 of Set 7 | ancud
# Processing Record 25 of Set 7 | lukiv
# Processing Record 26 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 7 | kongolo
# Processing Record 28 of Set 7 | jumla
# Processing Record 29 of Set 7 | kudahuvadhoo
# Processing Record 30 of Set 7 | vanavara
# Processing Record 31 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 7 | christiansburg
# Processing Record 33 of Set 7 | sinnar
# Processing Record 34 of Set 7 | ketchikan
# Processing Record 35 of Set 7 | mindelo
# Processing Record 36 of Set 7 | mokhotlong
# Processing Record 37 of Set 7 | omsukchan
# Processing Record 38 of Set 7 | nishihara
# Processing Record 39 of Set 7 | batasan
# Processing Record 40 of Set 7 | daru
# Processing Record 41 of Set 7 | fayaoue
# Processing Record 42 of Set 7 | port lincoln
# Processing Record 43 of Set 7 | vila franca do campo
# Processing Record 44 of Set 7 | chissamba
# Processing Record 45 of Set 7 | kadaya
# Processing Record 46 of Set 7 | matara
# Processing Record 47 of Set 7 | cidreira
# Processing Record 48 of Set 7 | akhalgori
# Processing Record 49 of Set 7 | homer
# Processing Record 50 of Set 7 | faanui
# Processing Record 1 of Set 8 | whitehorse
# Processing Record 2 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 3 of Set 8 | clyde river
# Processing Record 4 of Set 8 | aliaga
# Processing Record 5 of Set 8 | quang ngai
# Processing Record 6 of Set 8 | karratha
# Processing Record 7 of Set 8 | nome
# Processing Record 8 of Set 8 | flinders
# Processing Record 9 of Set 8 | pafos
# Processing Record 10 of Set 8 | san juan
# Processing Record 11 of Set 8 | quixada
# Processing Record 12 of Set 8 | qafsah
# City not found. Skipping...
# Processing Record 13 of Set 8 | arcata
# Processing Record 14 of Set 8 | parabel
# Processing Record 15 of Set 8 | puerto escondido
# Processing Record 16 of Set 8 | najran
# Processing Record 17 of Set 8 | gornet
# Processing Record 18 of Set 8 | muisne
# Processing Record 19 of Set 8 | kropotkin
# Processing Record 20 of Set 8 | naberera
# Processing Record 21 of Set 8 | dingle
# Processing Record 22 of Set 8 | fasa
# Processing Record 23 of Set 8 | pontianak
# Processing Record 24 of Set 8 | kruisfontein
# Processing Record 25 of Set 8 | angoche
# Processing Record 26 of Set 8 | mayahi
# Processing Record 27 of Set 8 | smithers
# Processing Record 28 of Set 8 | lyuban
# Processing Record 29 of Set 8 | kargasok
# Processing Record 30 of Set 8 | vao
# Processing Record 31 of Set 8 | parrita
# Processing Record 32 of Set 8 | san patricio
# Processing Record 33 of Set 8 | santa fe
# Processing Record 34 of Set 8 | krasnomayskiy
# Processing Record 35 of Set 8 | kapit
# Processing Record 36 of Set 8 | lebu
# Processing Record 37 of Set 8 | malanje
# Processing Record 38 of Set 8 | bilibino
# Processing Record 39 of Set 8 | fortuna
# Processing Record 40 of Set 8 | yashalta
# Processing Record 41 of Set 8 | hobyo
# Processing Record 42 of Set 8 | obo
# Processing Record 43 of Set 8 | burnie
# Processing Record 44 of Set 8 | finnsnes
# Processing Record 45 of Set 8 | shalinskoye
# Processing Record 46 of Set 8 | vila
# Processing Record 47 of Set 8 | nizhniy ingash
# Processing Record 48 of Set 8 | biryusinsk
# Processing Record 49 of Set 8 | scarborough
# Processing Record 50 of Set 8 | mandiana
# Processing Record 1 of Set 9 | bathsheba
# Processing Record 2 of Set 9 | tuatapere
# Processing Record 3 of Set 9 | nieuw amsterdam
# Processing Record 4 of Set 9 | kenai
# Processing Record 5 of Set 9 | estacion coahuila
# Processing Record 6 of Set 9 | ikongo
# Processing Record 7 of Set 9 | ilulissat
# Processing Record 8 of Set 9 | arawa
# Processing Record 9 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 9 | quatre cocos
# Processing Record 11 of Set 9 | gubkinskiy
# Processing Record 12 of Set 9 | usakos
# Processing Record 13 of Set 9 | itanhem
# Processing Record 14 of Set 9 | portland
# Processing Record 15 of Set 9 | shaunavon
# Processing Record 16 of Set 9 | amga
# Processing Record 17 of Set 9 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 9 | birin
# Processing Record 19 of Set 9 | cururupu
# Processing Record 20 of Set 9 | memphis
# Processing Record 21 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 22 of Set 9 | avanigadda
# Processing Record 23 of Set 9 | machinga
# Processing Record 24 of Set 9 | acapulco
# Processing Record 25 of Set 9 | codrington
# Processing Record 26 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 27 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 9 | moerai
# Processing Record 29 of Set 9 | komsomolskiy
# Processing Record 30 of Set 9 | la romana
# Processing Record 31 of Set 9 | maloy
# Processing Record 32 of Set 9 | los llanos de aridane
# Processing Record 33 of Set 9 | riyadh
# Processing Record 34 of Set 9 | kamenskiy
# Processing Record 35 of Set 9 | kenora
# Processing Record 36 of Set 9 | ouesso
# Processing Record 37 of Set 9 | mto wa mbu
# Processing Record 38 of Set 9 | altonia
# City not found. Skipping...
# Processing Record 39 of Set 9 | fare
# Processing Record 40 of Set 9 | adre
# Processing Record 41 of Set 9 | mbacke
# City not found. Skipping...
# Processing Record 42 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 43 of Set 9 | shimoda
# Processing Record 44 of Set 9 | carbonia
# Processing Record 45 of Set 9 | buritizeiro
# Processing Record 46 of Set 9 | constitucion
# Processing Record 47 of Set 9 | taoudenni
# Processing Record 48 of Set 9 | paita
# Processing Record 49 of Set 9 | barentu
# Processing Record 50 of Set 9 | atar
# Processing Record 1 of Set 10 | anloga
# Processing Record 2 of Set 10 | narrabri
# Processing Record 3 of Set 10 | kavieng
# Processing Record 4 of Set 10 | mount isa
# Processing Record 5 of Set 10 | dunedin
# Processing Record 6 of Set 10 | lichinga
# Processing Record 7 of Set 10 | isangel
# Processing Record 8 of Set 10 | lincoln
# Processing Record 9 of Set 10 | regina
# Processing Record 10 of Set 10 | itarema
# Processing Record 11 of Set 10 | krasnyy luch
# Processing Record 12 of Set 10 | barsovo
# Processing Record 13 of Set 10 | namatanai
# Processing Record 14 of Set 10 | camaguey
# Processing Record 15 of Set 10 | soyo
# Processing Record 16 of Set 10 | sao raimundo nonato
# Processing Record 17 of Set 10 | araouane
# Processing Record 18 of Set 10 | pirot
# Processing Record 19 of Set 10 | istmina
# Processing Record 20 of Set 10 | kendallville
# Processing Record 21 of Set 10 | aswan
# Processing Record 22 of Set 10 | lafia
# Processing Record 23 of Set 10 | weligama
# Processing Record 24 of Set 10 | rock springs
# Processing Record 25 of Set 10 | gerardmer
# Processing Record 26 of Set 10 | alice springs
# Processing Record 27 of Set 10 | belmonte
# Processing Record 28 of Set 10 | fastovetskaya
# Processing Record 29 of Set 10 | kyra
# Processing Record 30 of Set 10 | tobe
# Processing Record 31 of Set 10 | iracoubo
# Processing Record 32 of Set 10 | valley city
# Processing Record 33 of Set 10 | okhotsk
# Processing Record 34 of Set 10 | seoul
# Processing Record 35 of Set 10 | port shepstone
# Processing Record 36 of Set 10 | jacareacanga
# Processing Record 37 of Set 10 | inirida
# Processing Record 38 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 39 of Set 10 | pundaguitan
# Processing Record 40 of Set 10 | sao paulo de olivenca
# Processing Record 41 of Set 10 | buseresere
# Processing Record 42 of Set 10 | san
# Processing Record 43 of Set 10 | korla
# Processing Record 44 of Set 10 | chama
# Processing Record 45 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 46 of Set 10 | liverpool
# Processing Record 47 of Set 10 | praia da vitoria
# Processing Record 48 of Set 10 | payo
# Processing Record 49 of Set 10 | lluta
# Processing Record 50 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 11 | ajdovscina
# Processing Record 2 of Set 11 | koboko
# Processing Record 3 of Set 11 | keetmanshoop
# Processing Record 4 of Set 11 | tanshui
# City not found. Skipping...
# Processing Record 5 of Set 11 | ixtapa
# Processing Record 6 of Set 11 | abong mbang
# Processing Record 7 of Set 11 | bonnyville
# Processing Record 8 of Set 11 | churapcha
# Processing Record 9 of Set 11 | agadez
# Processing Record 10 of Set 11 | santiago de cao
# Processing Record 11 of Set 11 | veraval
# Processing Record 12 of Set 11 | takoradi
# Processing Record 13 of Set 11 | makung
# City not found. Skipping...
# Processing Record 14 of Set 11 | halifax
# Processing Record 15 of Set 11 | presidencia roque saenz pena
# Processing Record 16 of Set 11 | walvis bay
# Processing Record 17 of Set 11 | mayumba
# Processing Record 18 of Set 11 | jutai
# Processing Record 19 of Set 11 | agapovka
# Processing Record 20 of Set 11 | damghan
# Processing Record 21 of Set 11 | baghdad
# Processing Record 22 of Set 11 | plettenberg bay
# Processing Record 23 of Set 11 | monchique
# Processing Record 24 of Set 11 | grand valley
# Processing Record 25 of Set 11 | esperance
# Processing Record 26 of Set 11 | ola
# Processing Record 27 of Set 11 | puerto narino
# Processing Record 28 of Set 11 | jibuti
# Processing Record 29 of Set 11 | general pico
# Processing Record 30 of Set 11 | urumqi
# Processing Record 31 of Set 11 | morant bay
# Processing Record 32 of Set 11 | seuzach
# Processing Record 33 of Set 11 | puksoozero
# Processing Record 34 of Set 11 | contamana
# Processing Record 35 of Set 11 | north bend
# Processing Record 36 of Set 11 | skjervoy
# Processing Record 37 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 38 of Set 11 | fuyang
# Processing Record 39 of Set 11 | sangin
# Processing Record 40 of Set 11 | grand gaube
# Processing Record 41 of Set 11 | pascagoula
# Processing Record 42 of Set 11 | miri
# Processing Record 43 of Set 11 | carutapera
# Processing Record 44 of Set 11 | derac
# Processing Record 45 of Set 11 | yeppoon
# Processing Record 46 of Set 11 | kilindoni
# Processing Record 47 of Set 11 | cooma
# Processing Record 48 of Set 11 | naftah
# City not found. Skipping...
# Processing Record 49 of Set 11 | pemangkat
# Processing Record 50 of Set 11 | mufumbwe
# Processing Record 1 of Set 12 | yerbogachen
# Processing Record 2 of Set 12 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 12 | bozoum
# Processing Record 4 of Set 12 | porto novo
# Processing Record 5 of Set 12 | mecca
# Processing Record 6 of Set 12 | bucerias
# Processing Record 7 of Set 12 | port blair
# Processing Record 8 of Set 12 | yuzhnyy
# Processing Record 9 of Set 12 | basoko
# Processing Record 10 of Set 12 | nouadhibou
# Processing Record 11 of Set 12 | oytal
# Processing Record 12 of Set 12 | kwakoa
# Processing Record 13 of Set 12 | rafai
# Processing Record 14 of Set 12 | makokou
# Processing Record 15 of Set 12 | hasaki
# Processing Record 16 of Set 12 | saint-augustin
# Processing Record 17 of Set 12 | henties bay
# Processing Record 18 of Set 12 | bac lieu
# Processing Record 19 of Set 12 | boralday
# Processing Record 20 of Set 12 | houma
# Processing Record 21 of Set 12 | donetsk
# Processing Record 22 of Set 12 | tatarsk
# Processing Record 23 of Set 12 | syracuse
# Processing Record 24 of Set 12 | rundu
# Processing Record 25 of Set 12 | ambanja
# Processing Record 26 of Set 12 | gibara
# Processing Record 27 of Set 12 | hamilton
# Processing Record 28 of Set 12 | lantawan
# Processing Record 29 of Set 12 | kaabong
# Processing Record 30 of Set 12 | estreito
# Processing Record 31 of Set 12 | deputatskiy
# Processing Record 32 of Set 12 | zhelyabovka
# Processing Record 33 of Set 12 | meulaboh
# Processing Record 34 of Set 12 | lyaskelya
# Processing Record 35 of Set 12 | sabha
# Processing Record 36 of Set 12 | kentau
# Processing Record 37 of Set 12 | artvin
# Processing Record 38 of Set 12 | luena
# Processing Record 39 of Set 12 | te anau
# Processing Record 40 of Set 12 | kuandian
# Processing Record 41 of Set 12 | buala
# Processing Record 42 of Set 12 | trat
# Processing Record 43 of Set 12 | iquique
# Processing Record 44 of Set 12 | castlerea
# Processing Record 45 of Set 12 | nador
# Processing Record 46 of Set 12 | gurupi
# Processing Record 47 of Set 12 | flin flon
# Processing Record 48 of Set 12 | nizhniy bestyakh
# Processing Record 49 of Set 12 | chimoio
# Processing Record 50 of Set 12 | santa rosa
# Processing Record 1 of Set 13 | svetlyy
# Processing Record 2 of Set 13 | sao miguel do tapuio
# Processing Record 3 of Set 13 | paso de los toros
# Processing Record 4 of Set 13 | dawei
# Processing Record 5 of Set 13 | altay
# Processing Record 6 of Set 13 | san pedro de macoris
# Processing Record 7 of Set 13 | hervey bay
# Processing Record 8 of Set 13 | sinazongwe
# Processing Record 9 of Set 13 | mapiripan
# Processing Record 10 of Set 13 | norman wells
# Processing Record 11 of Set 13 | la ronge
# Processing Record 12 of Set 13 | tunduru
# City not found. Skipping...
# Processing Record 13 of Set 13 | wilhelmsburg
# Processing Record 14 of Set 13 | brookhaven
# Processing Record 15 of Set 13 | sabancuy
# Processing Record 16 of Set 13 | yalchiki
# City not found. Skipping...
# Processing Record 17 of Set 13 | villa bruzual
# Processing Record 18 of Set 13 | san jose
# Processing Record 19 of Set 13 | dhulian
# Processing Record 20 of Set 13 | roebourne
# Processing Record 21 of Set 13 | husavik
# Processing Record 22 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 23 of Set 13 | batemans bay
# Processing Record 24 of Set 13 | yar-sale
# Processing Record 25 of Set 13 | zyryanovsk
# Processing Record 26 of Set 13 | katangi
# Processing Record 27 of Set 13 | beipiao
# Processing Record 28 of Set 13 | maniitsoq
# Processing Record 29 of Set 13 | buta
# Processing Record 30 of Set 13 | yarmouth
# Processing Record 31 of Set 13 | yeniseysk
# Processing Record 32 of Set 13 | tawau
# Processing Record 33 of Set 13 | talakan
# Processing Record 34 of Set 13 | mount pleasant
# Processing Record 35 of Set 13 | berdigestyakh
# Processing Record 36 of Set 13 | great falls
# Processing Record 37 of Set 13 | gat
# Processing Record 38 of Set 13 | rawson
# Processing Record 39 of Set 13 | northam
# Processing Record 40 of Set 13 | naenwa
# City not found. Skipping...
# Processing Record 41 of Set 13 | teseney
# Processing Record 42 of Set 13 | san miguel
# Processing Record 43 of Set 13 | semnan
# Processing Record 44 of Set 13 | aurora
# Processing Record 45 of Set 13 | sotouboua
# Processing Record 46 of Set 13 | la grande
# Processing Record 47 of Set 13 | eldikan
# City not found. Skipping...
# Processing Record 48 of Set 13 | emerald
# Processing Record 49 of Set 13 | shelburne
# Processing Record 50 of Set 13 | mehamn
# Processing Record 1 of Set 14 | jega
# Processing Record 2 of Set 14 | rio gallegos
# Processing Record 3 of Set 14 | chesma
# Processing Record 4 of Set 14 | palmer
# Processing Record 5 of Set 14 | eirunepe
# Processing Record 6 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 14 | lovozero
# Processing Record 8 of Set 14 | yumen
# Processing Record 9 of Set 14 | saucillo
# Processing Record 10 of Set 14 | nyurba
# Processing Record 11 of Set 14 | alcudia
# Processing Record 12 of Set 14 | bhag
# Processing Record 13 of Set 14 | peniche
# Processing Record 14 of Set 14 | haines junction
# Processing Record 15 of Set 14 | pitimbu
# Processing Record 16 of Set 14 | nattam
# Processing Record 17 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 18 of Set 14 | kurush
# Processing Record 19 of Set 14 | washington
# Processing Record 20 of Set 14 | arlit
# Processing Record 21 of Set 14 | rio grande
# Processing Record 22 of Set 14 | bulawayo
# Processing Record 23 of Set 14 | zhanakorgan
# Processing Record 24 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 25 of Set 14 | kamenka
# Processing Record 26 of Set 14 | sulangan
# Processing Record 27 of Set 14 | bitam
# Processing Record 28 of Set 14 | la rioja
# Processing Record 29 of Set 14 | svetlogorsk
# Processing Record 30 of Set 14 | victor harbor
# Processing Record 31 of Set 14 | sestri levante
# Processing Record 32 of Set 14 | addanki
# Processing Record 33 of Set 14 | pandaria
# Processing Record 34 of Set 14 | ileanda
# Processing Record 35 of Set 14 | forest
# Processing Record 36 of Set 14 | lamu
# Processing Record 37 of Set 14 | wanlaweyn
# Processing Record 38 of Set 14 | galiwinku
# City not found. Skipping...
# Processing Record 39 of Set 14 | ahipara
# Processing Record 40 of Set 14 | phuket
# Processing Record 41 of Set 14 | sitamau
# Processing Record 42 of Set 14 | penzberg
# Processing Record 43 of Set 14 | mpika
# Processing Record 44 of Set 14 | naryan-mar
# Processing Record 45 of Set 14 | huntington
# Processing Record 46 of Set 14 | sioux lookout
# Processing Record 47 of Set 14 | sterling
# Processing Record 48 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 14 | nakonde
# Processing Record 50 of Set 14 | turka
# Processing Record 1 of Set 15 | arzgir
# Processing Record 2 of Set 15 | mokolo
# Processing Record 3 of Set 15 | peruibe
# Processing Record 4 of Set 15 | jvari
# Processing Record 5 of Set 15 | san vicente
# Processing Record 6 of Set 15 | ovalle
# Processing Record 7 of Set 15 | vestbygda
# City not found. Skipping...
# Processing Record 8 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 9 of Set 15 | hay river
# Processing Record 10 of Set 15 | sinkat
# City not found. Skipping...
# Processing Record 11 of Set 15 | charters towers
# Processing Record 12 of Set 15 | balkanabat
# Processing Record 13 of Set 15 | maceio
# Processing Record 14 of Set 15 | ucluelet
# Processing Record 15 of Set 15 | hami
# Processing Record 16 of Set 15 | hualmay
# Processing Record 17 of Set 15 | sao joao da barra
# Processing Record 18 of Set 15 | sambava
# Processing Record 19 of Set 15 | chuchkovo
# Processing Record 20 of Set 15 | erenhot
# Processing Record 21 of Set 15 | likasi
# Processing Record 22 of Set 15 | kieta
# Processing Record 23 of Set 15 | kaya
# Processing Record 24 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 25 of Set 15 | chivor
# Processing Record 26 of Set 15 | sibolga
# Processing Record 27 of Set 15 | alampur
# Processing Record 28 of Set 15 | basco
# Processing Record 29 of Set 15 | kamaishi
# Processing Record 30 of Set 15 | chickasha
# Processing Record 31 of Set 15 | zhanaozen
# Processing Record 32 of Set 15 | rewari
# Processing Record 33 of Set 15 | biltine
# Processing Record 34 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 15 | babanusah
# City not found. Skipping...
# Processing Record 36 of Set 15 | batagay
# Processing Record 37 of Set 15 | lubango
# Processing Record 38 of Set 15 | menongue
# Processing Record 39 of Set 15 | olinda
# Processing Record 40 of Set 15 | gavrilovka vtoraya
# Processing Record 41 of Set 15 | litoral del san juan
# City not found. Skipping...
# Processing Record 42 of Set 15 | aberfoyle
# Processing Record 43 of Set 15 | arman
# Processing Record 44 of Set 15 | mantua
# Processing Record 45 of Set 15 | cuenca
# Processing Record 46 of Set 15 | taltal
# Processing Record 47 of Set 15 | reconquista
# Processing Record 48 of Set 15 | nelson
# Processing Record 49 of Set 15 | gizo
# Processing Record 50 of Set 15 | bairnsdale
# Processing Record 1 of Set 16 | matagami
# Processing Record 2 of Set 16 | atka
# City not found. Skipping...
# Processing Record 3 of Set 16 | bethanien
# Processing Record 4 of Set 16 | benjamin aceval
# Processing Record 5 of Set 16 | truckee
# Processing Record 6 of Set 16 | san ramon de la nueva oran
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# 0                        Jieshi  22.8134  115.8257     76.57        84
# 1                      Tasiilaq  65.6145  -37.6368     41.16        91
# 2                        Albany  42.6001  -73.9662     90.25        51
# 3                       Rikitea -23.1203 -134.9692     76.64        84
# 4                        Namibe -15.1961   12.1522     74.07        54
# ..                          ...      ...       ...       ...       ...
# 681                    Matagami  49.7502  -77.6328     84.31        39
# 682                   Bethanien -26.5020   17.1583     55.92        35
# 683             Benjamin Aceval -24.9667  -57.5667     68.59        95
# 684                     Truckee  39.3280 -120.1833     83.55        30
# 685  San Ramon De La Nueva Oran -23.1322  -64.3260     65.43        82
#
#      Cloudiness  Wind Speed Country       Description
# 0            18       16.62      CN        few clouds
# 1            98        5.12      GL   overcast clouds
# 2            45        1.99      US  scattered clouds
# 3            98       15.88      PF   overcast clouds
# 4            50        8.39      AO  scattered clouds
# ..          ...         ...     ...               ...
# 681           1        9.46      CA         clear sky
# 682           0       15.23      NA         clear sky
# 683          79        6.31      PY     broken clouds
# 684           1       20.71      US         clear sky
# 685          83        3.18      AR     broken clouds
#
# [686 rows x 9 columns]

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                            City Country      Lat       Lng  Max Temp  \
# 0                        Jieshi      CN  22.8134  115.8257     76.57
# 1                      Tasiilaq      GL  65.6145  -37.6368     41.16
# 2                        Albany      US  42.6001  -73.9662     90.25
# 3                       Rikitea      PF -23.1203 -134.9692     76.64
# 4                        Namibe      AO -15.1961   12.1522     74.07
# ..                          ...     ...      ...       ...       ...
# 681                    Matagami      CA  49.7502  -77.6328     84.31
# 682                   Bethanien      NA -26.5020   17.1583     55.92
# 683             Benjamin Aceval      PY -24.9667  -57.5667     68.59
# 684                     Truckee      US  39.3280 -120.1833     83.55
# 685  San Ramon De La Nueva Oran      AR -23.1322  -64.3260     65.43
#
#      Humidity  Cloudiness  Wind Speed       Description
# 0          84          18       16.62        few clouds
# 1          91          98        5.12   overcast clouds
# 2          51          45        1.99  scattered clouds
# 3          84          98       15.88   overcast clouds
# 4          54          50        8.39  scattered clouds
# ..        ...         ...         ...               ...
# 681        39           1        9.46         clear sky
# 682        35           0       15.23         clear sky
# 683        95          79        6.31     broken clouds
# 684        30           1       20.71         clear sky
# 685        82          83        3.18     broken clouds
#
# [686 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
